# %%
rohit=[105,203,1]

# %%
import numpy as np

# %%
np_scores=np.array(rohit)

# %%
type(np_scores)
# Out:
# numpy.ndarray

# %%
[True,1,2]+[3,4,False]
# Out:
# [True, 1, 2, 3, 4, False]

# %%
np.array([True,1,2])+np.array([3,4,False])
# Out:
# array([4, 5, 2])

# %%
np.array([True,1,2])*5
# Out:
# array([ 5,  5, 10])

# %%
np.array(["Akshay"])+np.array("Patel")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c18fa50e2dda> in <module>
# ----> 1 np.array(["Akshay"])+np.array("Patel")
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U6') dtype('<U6') dtype('<U6')

# %%
[1,1,1].index(1)
# Out:
# 0

# %%
np.array([1.0,1,2])
# Out:
# array([1., 1., 2.])

# %%
testcric=[
    [180,78],
    [215,102],
    [210,98],
    [188,75]
]

# %%
np_test=np.array(testcric)

# %%
np_test.shape
# Out:
# (4, 2)

# %%
np_test.ndim
# Out:
# 2

# %%
np_test[0][1]
# Out:
# 78

# %%
np_test[:,1]
# Out:
# array([ 78, 102,  98,  75])
